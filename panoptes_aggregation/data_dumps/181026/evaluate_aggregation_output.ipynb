# %% [markdown]
# ### [Reading csv files in python](https://aggregation-caesar.zooniverse.org/Scripts.html#reading-csv-files-in-python)

# %%
import pandas
from panoptes_aggregation.csv_utils import unjson_dataframe

# %%
# the `data.*` columns are read in as strings instead of arrays
data = pandas.read_csv('survey_reducer_001.csv')

# %%
data.head()
# Out:
#    subject_id  workflow_id task         reducer        data.choice  \
# 0     5515445         3101   T1  survey_reducer  blackbilledmagpie
# 1     5515446         3101   T1  survey_reducer  blackbilledmagpie
# 2     5515447         3101   T1  survey_reducer             coyote
# 3     5515447         3101   T1  survey_reducer      unknownanimal
# 4     5515448         3101   T1  survey_reducer                elk
#
#    data.total_vote_count  data.choice_count data.aggregation_version  \
# 0                      8                  8                    2.0.1
# 1                      2                  2                    2.0.1
# 2                      5                  4                    2.0.1
# 3                      5                  1                    2.0.1
# 4                      9                  5                    2.0.1
#
#    data.answers_groupnumbers.15  data.answers_groupnumbers.610  \
# 0                           8.0                            NaN
# 1                           NaN                            1.0
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#                                                                  ...                                                                 \
# 0                                                                ...
# 1                                                                ...
# 2                                                                ...
# 3                                                                ...
# 4                                                                ...
#
#    data.answers_numberofindividuals.4  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeametallegband  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeawingtag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_numberofindividuals.10ormore  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeacoloredlegband  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_numberofindividuals.7  data.answers_numberofindividuals.5  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    data.answers_numberofindividuals.6  data.answers_numberofindividuals.8  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeatransmitter
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 27 columns]

# %%
# use unjson_dataframe to convert them to lists
# all values are updated in place leaving null values untouched
unjson_dataframe(data)

# %%
data.head()
# Out:
#    subject_id  workflow_id task         reducer        data.choice  \
# 0     5515445         3101   T1  survey_reducer  blackbilledmagpie
# 1     5515446         3101   T1  survey_reducer  blackbilledmagpie
# 2     5515447         3101   T1  survey_reducer             coyote
# 3     5515447         3101   T1  survey_reducer      unknownanimal
# 4     5515448         3101   T1  survey_reducer                elk
#
#    data.total_vote_count  data.choice_count data.aggregation_version  \
# 0                      8                  8                    2.0.1
# 1                      2                  2                    2.0.1
# 2                      5                  4                    2.0.1
# 3                      5                  1                    2.0.1
# 4                      9                  5                    2.0.1
#
#    data.answers_groupnumbers.15  data.answers_groupnumbers.610  \
# 0                           8.0                            NaN
# 1                           NaN                            1.0
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#                                                                  ...                                                                 \
# 0                                                                ...
# 1                                                                ...
# 2                                                                ...
# 3                                                                ...
# 4                                                                ...
#
#    data.answers_numberofindividuals.4  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeametallegband  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeawingtag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_numberofindividuals.10ormore  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeacoloredlegband  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    data.answers_numberofindividuals.7  data.answers_numberofindividuals.5  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    data.answers_numberofindividuals.6  data.answers_numberofindividuals.8  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    data.answers_canyouseeanyofthesethingsinthepictureifthereismorethanoneeagleincludealloptionsthatapplytothegroup.iseeatransmitter
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 27 columns]
